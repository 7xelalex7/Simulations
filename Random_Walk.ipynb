# %%
import random

def random_walk(n):
    """"Return coordinates afetr 'n' block random walk"""
    x = 0
    y = 0
    for i in range(n):
        step = random.choice(['N', 'S', 'E', 'W'])
        
        if step == 'N':
            y += 1
        elif step == 'S':
            y -= 1
        elif step == 'E':
            x += 1
        else:
            x -= 1
            
    return (x, y)

#for i in range(25):
#    walk = random_walk(10)
    #print (walk, "Distance from home = ", abs(walk[0]) + abs(walk[1]))
    
def random_walk_2(n):
    """"Return coordinates afetr 'n' block random walk"""
    x, y = 0, 0
    for i in range(n):
        (dx, dy) = random.choice([(0,1), (0,-1), (1,0), (-1,0)])
        x += dx
        y += dy
    return(x,y)
    
#for i in range(25):
#    walk = random_walk_2(10)
#    print(walk, "Distance from home = ", abs(walk[0]) + abs(walk[1]))

number_of_walks = 100000

for walk_length in range(1,51):
    no_transport = 0 # number of walks 4 or fewer blocks from home
    for i in range(number_of_walks):
        (x,y) = random_walk_2(walk_length)
        distance = abs(x) + abs(y)
        if distance <=5 :
            no_transport += 1
    no_transport_percentage = float(no_transport) / number_of_walks
    print("Walk size = ", walk_length, "/% of no transport = ", 100 * no_transport_percentage)
# Out:
# Walk size =  1 /% of no transport =  100.0
# Walk size =  2 /% of no transport =  100.0
# Walk size =  3 /% of no transport =  100.0
# Walk size =  4 /% of no transport =  100.0
# Walk size =  5 /% of no transport =  100.0
# Walk size =  6 /% of no transport =  93.867
# Walk size =  7 /% of no transport =  96.974
# Walk size =  8 /% of no transport =  86.335
# Walk size =  9 /% of no transport =  92.472
# Walk size =  10 /% of no transport =  79.201
# Walk size =  11 /% of no transport =  87.22999999999999
# Walk size =  12 /% of no transport =  72.98400000000001
# Walk size =  13 /% of no transport =  82.233
# Walk size =  14 /% of no transport =  67.46600000000001
# Walk size =  15 /% of no transport =  77.582
# Walk size =  16 /% of no transport =  62.511
# Walk size =  17 /% of no transport =  73.485
# Walk size =  18 /% of no transport =  58.096000000000004
# Walk size =  19 /% of no transport =  69.254
# Walk size =  20 /% of no transport =  54.606
# Walk size =  21 /% of no transport =  65.50200000000001
# Walk size =  22 /% of no transport =  50.748000000000005
# Walk size =  23 /% of no transport =  62.695
# Walk size =  24 /% of no transport =  48.154
# Walk size =  25 /% of no transport =  59.413000000000004
# Walk size =  26 /% of no transport =  45.286
# Walk size =  27 /% of no transport =  56.553
# Walk size =  28 /% of no transport =  43.1
# Walk size =  29 /% of no transport =  53.759
# Walk size =  30 /% of no transport =  40.786
# Walk size =  31 /% of no transport =  51.848000000000006
# Walk size =  32 /% of no transport =  38.677
# Walk size =  33 /% of no transport =  49.786
# Walk size =  34 /% of no transport =  36.929
# Walk size =  35 /% of no transport =  47.692
# Walk size =  36 /% of no transport =  35.568
# Walk size =  37 /% of no transport =  45.777
# Walk size =  38 /% of no transport =  33.703
# Walk size =  39 /% of no transport =  44.032
# Walk size =  40 /% of no transport =  32.417
# Walk size =  41 /% of no transport =  42.41
# Walk size =  42 /% of no transport =  31.186000000000003
# Walk size =  43 /% of no transport =  40.96
# Walk size =  44 /% of no transport =  30.085
# Walk size =  45 /% of no transport =  39.739000000000004
# Walk size =  46 /% of no transport =  29.319
# Walk size =  47 /% of no transport =  38.440999999999995
# Walk size =  48 /% of no transport =  28.273
# Walk size =  49 /% of no transport =  36.95
# Walk size =  50 /% of no transport =  27.033
